# %% [markdown]
# # Project - Classifying Variable Stars 📁

# %% [markdown]
# <details>
# <summary>
# <font size="5" color="#34896C">
# <b> Contributors </b>
# </font>
# </summary>
# <br>
# <font size = "4" color = "#BA453C">
# 1. Bhumika Bansal
# <br>
# 2. Lakshay Chawla
# </font>
# <br>
# </details>

# %% [markdown]
# ## Introduction 📰

# %% [markdown]
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 1. Problem Statement </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         Classifying periodic variable stars amongst 4 categories.
#         <br>
#         1. RR Lyrae
#         <br>
#         2. Cepheid
#         <br>
#         3. Long Period Variable Stars
#         <br>
#         4. Eclipsing Binary
#     </p>
#     </font>
# </details>
# <br>
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 2. Dataset Used </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         GAIA DR3
#         <br>
#         <br>
#         Link - http://cdn.gea.esac.esa.int/Gaia/gdr3/Photometry/epoch_photometry/
#     </p>
#     </font>
# </details>
# <br>
#
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 3. Inspiration </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         Just like every other child, when we were kids, we were fascinated by the endless sky and the innumerable number of stars that are unexplored (yet).
# <br>
# Always wanted to know more about stars and do something with astronomical data steered our team to take up a project using astronomical data.
# <br>
# <br>
# Here is a link of research paper that inspired the project - https://arxiv.org/pdf/2002.00994.pdf
#     </p>
#     </font>
# </details>

# %% [markdown]
# ## Let's Get Started ! 🏃🏻‍♂️

# %% [markdown]
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 1. What is GAIA Archive? </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         Gaia is a European space mission providing astrometry, photometry, and spectroscopy of more than 1000 million stars in the Milky Way. Also data for significant samples of extragalactic and Solar system objects is made available. The Gaia Archive contains deduced positions, parallaxes, proper motions, radial velocities, and brightnesses. Complementary information on multiplicity, photometric variability, and astrophysical parameters is provided for a large fraction of sources.
#         <br>
#         <br>
#         Reference - https://gea.esac.esa.int/archive/
#     </p>
#     </font>
# </details>
# <br>
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 2. What is the data we are looking for? </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         Let's get to our title.
#         <br>
#         Classifying Periodic Variable Stars.
#         <br>
#         Does this title excite any questions? Sure does, right?
#         <br>
#         Let's start listing a few of them :
#         <br>
#         <ol>
#             <li> What is a Variable Star? </li>
#             <li> What other types of Variable Stars exist other than periodic? </li>
#             <li> Why Periodic Variable stars? </li>
#             <li> How do you classify them? </li>
#         </ol>
#         <br>
#         We think these are enough for now.
#         <br>
#         Let's start answering them one by one!
#         <br>
#         <br>
#         <details>
#             <summary>
#                 <font size = "4" color = '#34896C'>
#                     <b> 2.1 What is a Variable Star? </b>
#                 </font>
#             </summary>
#             <br>
#             <font size = "3" color = "#654957">
#             <p>
#                 A variable star is, quite simply, a star that changes brightness. A star is considered variable if its apparent magnitude (brightness) is altered in any way from our perspective on Earth. These changes can occur over years or just fractions of a second, and can range from one-thousandth of a magnitude to 20 magnitudes.
#             </p>
#         </details>
#             <br>
#         <details>
#             <summary>
#                 <font size = "4" color = '#34896C'>
#                     <b> 2.2 What other types of Variable Stars exist other than periodic? </b>
#                 </font>
#             </summary>
#             <br>
#             <font size = "3" color = "#654957">
#             <p>
#                 Apart from a periodic variable star, there are 2 types of variable stars , namely Stochastic and Transients.
#             </p>
#         </details>
#             <br>
#         <details>
#             <summary>
#                 <font size = "4" color = '#34896C'>
#                     <b> 2.3 Why Periodic Variable stars? </b>
#                 </font>
#             </summary>
#             <br>
#             <font size = "3" color = "#654957">
#             <p>
#                 Periodic Variable stars are comparitively easy to detect and classify due to there periodic nature. So, in order to limit our scope we chose periodic variable stars.
#             </p>
#         </details>
#             <br>
#         <details>
#             <summary>
#                 <font size = "4" color = '#34896C'>
#                     <b> 2.4 How do you classify them? </b>
#                 </font>
#             </summary>
#             <br>
#             <font size = "3" color = "#654957">
#             <p>
#                 We will use the photometry data from GAIA Archive 3, to extract photometry data of the periodic variable stars and try to classify the subclasses of periodic variable stars. The subclasses we will be classifying are :
#                 <ol>
#                     <li>Cephieds</li>
#                     <li>Long Periodic Variable</li>
#                     <li>Eclipsing binaries</li>
#                     <li>RR Lyrae</li>
#                 </ol>
#             </p>
#         </details>
#     </p>
#     </font>
# </details>
# <br>
# <details>
#     <summary>
#         <font size = "5" color = '#34896C'>
#             <b> 3. How to extract data? </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         Now as we have established what data we need. There should be a way to extract the data instead of downloading each and every file ourself.
#         <br>
#         Here comes a time saving library named - <b><i>Astroquery</i></b>. This allows us to query the data and get the results straight to our work environment! that is - you guessed it, the jupyter notebook.
#     </p>
#     </font>
# </details>
# <br>
# <details>
#     <summary>
#         <font size = "5"color = '#34896C'>
#             <b> 4. Filtering of Data </b>
#         </font>
#     </summary>
#     <br>
#     <font size = "4" color = "#654957">
#     <p>
#         It is one thing to download the data and another thing to have it filtered. That requires some insights on data and some decisions which have to be made.
#         <br>
#         We will come back to filtering, first lets see the extraction process.
#     </p>
#     </font>
# </details>

# %% [markdown]
# ## Data Extraction 📝

# %% [markdown]
# <font size = "4" color = "#654957">
# Here comes our very first challenge.
# <br>
# How do you extract gigabytes of photometry data from the archive.
# <br>
# For this, we used a library named as <b> Astroquery </b>.
# <br>
# We extracted all the records for the 4 classes we want to classify. Took about 2 days to download the data. Make sure not to run the following cells.
#     </font>

# %%
## Libraries Used.
from astroquery.gaia import Gaia
import matplotlib.pyplot as plt
import math

# %%
def extract_dl_ind(datalink_dict, key, figsize = [15,5], fontsize = 12, linewidth = 2, show_legend = True, show_grid = True):
    ""
    "Extract individual DataLink products and export them to an Astropy Table"
    ""
    dl_out  = datalink_dict[key][0].to_table()
    if 'time' in dl_out.keys():
        plot_e_phot(dl_out, colours  = ['green', 'red', 'blue'], title = 'Epoch photometry', fontsize = fontsize, show_legend = show_legend, show_grid = show_grid, figsize = figsize)
    if 'wavelength' in dl_out.keys():
        if len(dl_out) == 343:  title = 'XP Sampled'
        if len(dl_out) == 2401: title = 'RVS'
        plot_sampled_spec(dl_out, color = 'blue', title = title, fontsize = fontsize, show_legend = False, show_grid = show_grid, linewidth = linewidth, legend = '', figsize = figsize)
    return dl_out


def plot_e_phot(inp_table, colours  = ['green', 'red', 'blue'], title = 'Epoch photometry', fontsize = 12, show_legend = True, show_grid = True, figsize = [15,5]):
    ""
    "Epoch photometry plotter. 'inp_table' MUST be an Astropy-table object."
    ""
    fig      = plt.figure(figsize=figsize)
    xlabel   = f'JD date [{inp_table["time"].unit}]'
    ylabel   = f'magnitude [{inp_table["mag"].unit}]'
    gbands   = ['G', 'RP', 'BP']
    colours  = iter(colours)

    plt.gca().invert_yaxis()
    for band in gbands:
        phot_set = inp_table[inp_table['band'] == band]
        plt.plot(phot_set['time'], phot_set['mag'], 'o', label = band, color = next(colours))
    make_canvas(title = title, xlabel = xlabel, ylabel = ylabel, fontsize= fontsize, show_legend=show_legend, show_grid = show_grid)
    plt.show()


def plot_sampled_spec(inp_table, color = 'blue', title = '', fontsize = 14, show_legend = True, show_grid = True, linewidth = 2, legend = '', figsize = [12,4], show_plot = True):
    ""
    "RVS & XP sampled spectrum plotter. 'inp_table' MUST be an Astropy-table object."
    ""
    if show_plot:
        fig      = plt.figure(figsize=figsize)
    xlabel   = f'Wavelength [{inp_table["wavelength"].unit}]'
    ylabel   = f'Flux [{inp_table["flux"].unit}]'
    plt.plot(inp_table['wavelength'], inp_table['flux'], '-', linewidth = linewidth, label = legend)
    make_canvas(title = title, xlabel = xlabel, ylabel = ylabel, fontsize= fontsize, show_legend=show_legend, show_grid = show_grid)
    if show_plot:
        plt.show()


def make_canvas(title = '', xlabel = '', ylabel = '', show_grid = False, show_legend = False, fontsize = 12):
    ""
    "Create generic canvas for plots"
    ""
    plt.title(title,    fontsize = fontsize)
    plt.xlabel(xlabel,  fontsize = fontsize)
    plt.ylabel(ylabel , fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    if show_grid:
        plt.grid()
    if show_legend:
        plt.legend(fontsize = fontsize*0.75)

# %%
query = f"SELECT source_id FROM gaiadr3.vari_eclipsing_binary"

job     = Gaia.launch_job_async(query)
results = job.get_results()
print(f'Table size (rows): {len(results)}')

# %%
total_ids = len(results['source_id'].value.data)
batch = 5000
ids = results['source_id'].value.data

# %%
retrieval_type = 'EPOCH_PHOTOMETRY'          # Options are: 'EPOCH_PHOTOMETRY', 'MCMC_GSPPHOT', 'MCMC_MSC', 'XP_SAMPLED', 'XP_CONTINUOUS', 'RVS', 'ALL'
data_structure = 'INDIVIDUAL'   # Options are: 'INDIVIDUAL', 'COMBINED', 'RAW'
data_release   = 'Gaia DR3'     # Options are: 'Gaia DR3' (default), 'Gaia DR2'

k=0
for i in range(0,math.ceil(total_ids/batch)):
    if i * batch > total_ids:
        batch_ids = ids[i*batch:total_ids]
    else:
        batch_ids = ids[i*batch:(i+1)*batch]
    datalink = Gaia.load_data(ids=batch_ids, data_release = data_release, retrieval_type=retrieval_type, data_structure = data_structure, verbose = False, output_file = None)
    dl_keys  = [inp for inp in datalink.keys()]
    dl_keys.sort()
    for dl_key in dl_keys:
        datalink[dl_key][0].to_table().to_pandas().to_csv("./vari_eclipsing_binary/"+dl_key+".csv")
    k+=batch
    print(k," downloaded")

print()
print(f'The following Datalink products have been downloaded:')
for dl_key in keys:
    print(f' * {dl_key}')

# %% [markdown]
# ## Filtering Data 📃

# %% [markdown]
# <font size = "4" color = "#654957">
#     Now, as you would have guessed the number of records is massive.
#     <br>
#     How much? Even we were curious, Let's have a look together.
# </font>

# %% [markdown]
# ### Take a look at the different stars 🌟

# %%
import pandas as pd
import numpy as np
import os
from prettytable import PrettyTable

# %%
classification_score_cep = pd.read_csv('Classification Scores/vari_cepheid_class_score.csv')
classification_score_rr = pd.read_csv('Classification Scores/vari_rrlyrae_class_score.csv')
classification_score_lpv = pd.read_csv('Classification Scores/vari_long_period_variable_class_score.csv')
classification_score_ecl = pd.read_csv('Classification Scores/vari_eclipsing_binary.csv')

# %%
pt = PrettyTable()
pt.field_names = ['Class','Number of Records']
pt.add_row(['Cepheid',classification_score_cep.shape[0]])
pt.add_row(['RR Lyrae',classification_score_rr.shape[0]])
pt.add_row(['Long Period',classification_score_lpv.shape[0]])
pt.add_row(['Eclipsing Binaries',classification_score_ecl.shape[0]])
print(pt)
# Out:
# +--------------------+-------------------+
# |       Class        | Number of Records |
# +--------------------+-------------------+
# |      Cepheid       |       16141       |
# |      RR Lyrae      |       297778      |
# |    Long Period     |      2325775      |
# | Eclipsing Binaries |      2184356      |
# +--------------------+-------------------+

# %% [markdown]
# ### Class Imbalance 1️⃣ 2️⃣ 3️⃣ 4️⃣

# %% [markdown]
# <font size = "4" color = "#654957">
#     Woah! almost 4.5M records. That's a lot.
#     <br>
#     Adding to our difficulty, these classes are highly imbalanced.
#     <br>
#     That means we have to filter our data.
#     <br>
#     To solve the class imbalance, also because we don't need 2M records for a class to classify, we settled on 100k files per class (Except Cepheids, because they only had 16k records.)
#     <br>
#     The best way to take 100k records was to look at the stars which had more confident classification, that is, a higher <i>best_class_score</i>.

# %%
DATASET_PATH = 'C:\\Users\\laksh\\OneDrive\\variable_stars\\vari_eclipsing_binary'

# %%
files = os.listdir(DATASET_PATH)
df = pd.read_csv('vari_eclipsing_binary.csv', index_col = 0)
df.sort_values(by = ['best_class_score'], ascending=False, inplace = True)
sources = df['source_id'].to_list()
no_of_records = {}
df_final = pd.DataFrame(columns = ['source_id', 'band','time' ,'mag','flux'])
count = 0
for records in tqdm(sources):
    i = f'EPOCH_PHOTOMETRY-Gaia DR3 {records}.xml.csv'
    if i not in files:
        continue
    temp = pd.read_csv(DATASET_PATH + '\\' + i, index_col=0)
    bands = ['G','RP','BP']
    for j in bands:
        dictionary = {'source_id' : temp['source_id'][0],
                  'band' : j,
                  'time' : [temp[temp['band'] == j]['time'].to_list()],
                  'mag' : [temp[temp['band'] == j]['mag'].to_list()],
                  'flux' : [temp[temp['band'] == j]['flux'].to_list()],
                  'label' : 'ECP' ## Change this for every class.
                 }
        df_temp = pd.DataFrame(dictionary)
        df_final = pd.concat([df_final,df_temp],axis = 0)
    count = count + 1
    if count == 100000:
            break

# %%
df_final.to_csv('final_vari_eclipsing_binary.csv')

# %% [markdown]
# ### Final Dataset 📍

# %%
df_lpv = pd.read_csv(r'Final Dataset/final_vari_long_period_variable.csv')
df_cep = pd.read_csv(r'Final Dataset/final_vari_cepheid.csv')
df_ecl = pd.read_csv(r'Final Dataset/final_vari_eclipsing_binary.csv')
df_rr = pd.read_csv(r'Final Dataset/final_vari_rr_lyrae.csv')

# %%
pt = PrettyTable()
pt.field_names = ['Class','Number of Records']
pt.add_row(['Cepheid',df_cep.shape[0]/3])
pt.add_row(['RR Lyrae',df_rr.shape[0]/3])
pt.add_row(['Long Period',df_lpv.shape[0]/3])
pt.add_row(['Eclipsing Binaries',df_ecl.shape[0]/3])
print(pt)
# Out:
# +--------------------+-------------------+
# |       Class        | Number of Records |
# +--------------------+-------------------+
# |      Cepheid       |      15021.0      |
# |      RR Lyrae      |      100000.0     |
# |    Long Period     |      100000.0     |
# | Eclipsing Binaries |      100000.0     |
# +--------------------+-------------------+

# %% [markdown]
# ## EDA 📊

# %% [markdown]
# <font size = "4" color = "#654957">
#     Extracting data was just the start of the challenge. Now, we need to have a look of what kind of data are we working with.
#     <br>
#     To start with, let's plot a few light curves for each class.
#     <br>
#     <font size = "4" color = "#ff0ae8">
#     What is a light curve you may ask?
#     </font>
#     <br>
#     In astronomy, a light curve is a graph of light intensity of a celestial object or region, as a function of time. The light is usually in a particular frequency interval or band.
#     <br>
#     For purposes of this project, we will be working with <font size = "4" color = "#0afa9e"><b>G</b></font>  band as it covers a larger wavelength.
# </font>

# %% [markdown]
# ![GaiaDR2Passbands.png](attachment:156af464-898e-4e74-86f5-bf6cc29a022c.png)

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from prettytable import PrettyTable

# %%
df_lpv = pd.read_csv(r'Final Dataset/final_vari_long_period_variable.csv')
df_cep = pd.read_csv(r'Final Dataset/final_vari_cepheid.csv')
df_ecl = pd.read_csv(r'Final Dataset/final_vari_eclipsing_binary.csv')
df_rr = pd.read_csv(r'Final Dataset/final_vari_rr_lyrae.csv')

# %%
def convert_to_list(string):
    return [float(i) if i != '' else 0 for i in string.split(', ')]

# %%
def process_dataset(df):
    columns = ['time', 'mag', 'flux']
    for i in columns:
        df[i] = df[i].apply(lambda x: x[1:-1])
        df = df[~df[i].isnull()]
        df[i] = df[i].apply(convert_to_list)
    return df

# %%
df_lpv = process_dataset(df_lpv)
df_cep = process_dataset(df_cep)
df_ecl = process_dataset(df_ecl)
df_rr = process_dataset(df_rr)

# %%
def plot_records(df,variable,name,band):
    if band == 'G':
        indexes = [0,3,6,9]
    if band == 'RP':
        indexes = [1,4,7,10]
    if band == 'BP':
        indexes = [2,5,8,11]
    fig, ax = plt.subplots(2,2,figsize = (20,8))
    ax[0][0].plot(df['time'][indexes[0]], df[variable][indexes[0]], color = band[0].lower())
    ax[0][0].scatter(df['time'][indexes[0]], df[variable][indexes[0]], color = 'black')
    ax[0][0].set_title('Record 1')
    ax[0][1].plot(df['time'][indexes[1]], df[variable][indexes[1]], color = 'black')
    ax[0][1].scatter(df['time'][indexes[1]], df[variable][indexes[1]], color = band[0].lower())
    ax[0][1].set_title('Record 2')
    ax[1][0].plot(df['time'][indexes[2]], df[variable][indexes[2]], color = band[0].lower())
    ax[1][0].scatter(df['time'][indexes[2]], df[variable][indexes[2]], color = 'black')
    ax[1][0].set_title('Record 3')
    ax[1][1].plot(df['time'][indexes[3]], df[variable][indexes[3]], color = band[0].lower())
    ax[1][1].scatter(df['time'][indexes[3]], df[variable][indexes[3]], color = 'black')
    ax[1][1].set_title('Record 4')
    plt.suptitle(f'Visualizing {variable} of class {name} of band {band}')
    for i in ax.flatten():
        i.set_xlabel('Time')
        i.set_ylabel(f'{variable}')
        i.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_records(df_lpv,'mag','LPV',"G")
plot_records(df_cep,'mag','CEP',"G")
plot_records(df_rr,'mag','RR',"G")
plot_records(df_ecl,'mag','ECL',"G")

# %%
plot_records(df_lpv,'flux','LPV',"G")
plot_records(df_cep,'flux','CEP',"G")
plot_records(df_rr,'flux','RR',"G")
plot_records(df_ecl,'flux','ECL',"G")

# %% [markdown]
# #### Observations

# %% [markdown]
# <font size = "4" color = "#654957">
#     From the above plots, we are able to identify a few things.
#     <ol>
#         <li> We need not use magnitude as well as flux as they are related -> magnitude = -2.5 log_10(flux) + constant (where the constant is named Zero Point Z_p)</li>
#         <li> For LPV class, the light curve seems to be comparitively smoother compared to other classes.</li>
#         <li> For RR Lyrae and Cepheids, the light curve is very errotic, implying that they change magnitudde quite frequently.</li>
#         <li> For Eclipsing Binaries, there seems to be 2 peaks, which is expected as these are 2 stars revolving around each other.</li>
#     </ol>
# </font>

# %%
def get_statistics(df, band, variable):
    temp =df[df['band'] == band] 
    arr_temp = np.hstack(temp[variable])
    temp_df = pd.DataFrame(arr_temp, columns = [variable])
    return temp_df.describe()

# %%
def print_statistics(df,variable,name,band):
    temp = get_statistics(df,band,variable)
    pt = PrettyTable()
    pt.field_names = ['Statistic','Value']
    print(f'Statistics of {variable} for class {name}.')
    for i in range(len(temp)):
        pt.add_row([temp.index[i],round(temp[variable][temp.index[i]],4)])
    print(pt)

# %%
print_statistics(df_lpv,'mag','LPV',"G")
print_statistics(df_cep,'mag','CEP',"G")
print_statistics(df_rr,'mag','RR',"G")
print_statistics(df_ecl,'mag','ECL',"G")
# Out:
# Statistics of mag for class LPV.
# +-----------+-----------+
# | Statistic |   Value   |
# +-----------+-----------+
# |   count   | 4767618.0 |
# |    mean   |   12.354  |
# |    std    |   1.6637  |
# |    min    |   2.8275  |
# |    25%    |  11.3886  |
# |    50%    |  12.5725  |
# |    75%    |  13.5124  |
# |    max    |  20.8953  |
# +-----------+-----------+
# Statistics of mag for class CEP.
# +-----------+----------+
# | Statistic |  Value   |
# +-----------+----------+
# |   count   | 725008.0 |
# |    mean   | 15.7985  |
# |    std    |  2.0178  |
# |    min    |  3.0658  |
# |    25%    |  15.145  |
# |    50%    | 16.0514  |
# |    75%    | 17.0433  |
# |    max    | 22.4199  |
# +-----------+----------+
# Statistics of mag for class RR.
# +-----------+-----------+
# | Statistic |   Value   |
# +-----------+-----------+
# |   count   | 4759737.0 |
# |    mean   |  17.3009  |
# |    std    |   1.6783  |
# |    min    |   9.109   |
# |    25%    |  16.0994  |
# ...

# %%
print_statistics(df_lpv,'flux','LPV',"G")
print_statistics(df_cep,'flux','CEP',"G")
print_statistics(df_rr,'flux','RR',"G")
print_statistics(df_ecl,'flux','ECL',"G")
# Out:
# Statistics of flux for class LPV.
# +-----------+-----------------+
# | Statistic |      Value      |
# +-----------+-----------------+
# |   count   |    4767618.0    |
# |    mean   |   1025249.0957  |
# |    std    |   4892843.9951  |
# |    min    |     82.5687     |
# |    25%    |    74130.9474   |
# |    50%    |   176175.7911   |
# |    75%    |   524204.4865   |
# |    max    | 1392962505.2136 |
# +-----------+-----------------+
# Statistics of flux for class CEP.
# +-----------+-----------------+
# | Statistic |      Value      |
# +-----------+-----------------+
# |   count   |     725008.0    |
# |    mean   |   539978.5197   |
# |    std    |  10588710.0704  |
# |    min    |     20.2761     |
# |    25%    |    2868.3331    |
# |    50%    |    7151.2705    |
# |    75%    |    16479.4106   |
# |    max    | 1118426733.0415 |
# +-----------+-----------------+
# Statistics of flux for class RR.
# +-----------+--------------+
# | Statistic |    Value     |
# ...

# %% [markdown]
# #### Observations

# %% [markdown]
# <font size = "4" color = "#654957">
#     From the statistics of the classes, we can notice a few things.
#     <ol>
#         <li> Mean value of magnitude of LPV is comparitively less than other stars implying that they are more bright(Thank the astronomer Hipparcos)</li>
#         <li> Standard Deviation of all the stars is very less, which means that we probably don't need to perform any scaling.</li>
#     </ol>
# </font>

# %%
list1 = [j-df_lpv['time'][0][i-1] if i !=0 else 0 for i,j in enumerate(df_lpv['time'][0])]
list2 = [j-df_lpv['time'][3][i-1] if i !=0 else 0 for i,j in enumerate(df_lpv['time'][3])]

# %%
pt = PrettyTable()
print('Time difference between consecutive observations of a particular record.')
pt.field_names = ['Record 1','Record 2']
for i in range(1,11):
    pt.add_row([round(list1[i],4),round(list2[i],4)])
print(pt)
# Out:
# Time difference between consecutive observations of a particular record.
# +----------+----------+
# | Record 1 | Record 2 |
# +----------+----------+
# | 27.1631  |  0.074   |
# |  0.074   |  0.1761  |
# | 23.9947  |  0.074   |
# | 125.435  | 34.3084  |
# |  0.074   |  0.074   |
# | 30.4157  | 31.9772  |
# |  0.074   | 19.4243  |
# | 22.6764  |  0.074   |
# |  0.074   | 93.6076  |
# | 145.4916 |  0.1761  |
# +----------+----------+

# %% [markdown]
# #### Observations

# %% [markdown]
# <font size = "4" color = "#654957">
#     One important observation from light curves was that the points did not seem to be in regular intervals, that is , sometimes stacked, sometimes very far apart.
#     <br>
#     The above output points to the same thing. The difference between consecutive magnitudes of a record is not equal. Adding to that, multiple records have  different time intervals.
#     <br>
#     This imposes a new challenge as we can't treat all the records similarly.
#     <br>
#     How to deal with this? I don't know, let's start merging the datasets and see if that even matters.

# %% [markdown]
# ## Merging the final datasets 📌

# %% [markdown]
# <font size = "4" color = "#654957">
#     For now, we have 4 csv files corresponding to each class. We will concat these files and then separate them based on band data.
#     <br>
#     The final result will be 3 csv files corresponding to observatoins of each band.
# </font>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df_lpv = pd.read_csv(r'Final Dataset/final_vari_long_period_variable.csv')
df_cep = pd.read_csv(r'Final Dataset/final_vari_cepheid.csv')
df_ecl = pd.read_csv(r'Final Dataset/final_vari_eclipsing_binary.csv')
df_rr = pd.read_csv(r'Final Dataset/final_vari_rr_lyrae.csv')

# %%
final_df = pd.concat([df_cep, df_lpv], axis = 0)
final_df = pd.concat([final_df, df_ecl], axis = 0)
final_df = pd.concat([final_df, df_rr], axis = 0)

# %%
final_df_g = final_df[final_df['band'] == 'G']
final_df_rp = final_df[final_df['band'] == 'RP']
final_df_bp = final_df[final_df['band'] == 'BP']

# %%
final_df_g.to_csv('final_df_g_complete.csv')
final_df_rp.to_csv('final_df_rp_complete.csv')
final_df_bp.to_csv('final_df_bp_complete.csv')

# %% [markdown]
# ## Modelling 🧠

# %% [markdown]
# <font size = "4" color = "#654957">
#     Here comes the fun part. Making models and training them. But, for that we need to prepare the input to be fed to the model.
# </font>

# %% [markdown]
# ### Preparing the input

# %% [markdown]
# <font size = "4" color = "#654957">
#     To prepare data, we need to follow the following steps:
#     <ol>
#         <li> Import the G band data in a datafrme.</li>
#         <li> Convert the data columns of <font size = "4" color = "#ffaaee"><i>time, mag and flux</i></font> from string to list.</li>
#         <li> Define X as magnitude column and y as label column.</li>
#         <li> Transform y from classes to numbers to feed into the model.</li>
#         <li> Perform a tri-split to have train, validation and test data.</li>
#         <li> Pre-pad the X columns to maximum length to solve any randomness in lengths</li>
#         <li> Convert tensorflow datasets for train_data, validation_data and test_data.</li>
#     </ol>
# </font>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Embedding, SimpleRNN, Input, Reshape, GRU, LSTM
from tensorflow.keras.preprocessing import sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
AUTOTUNE = tf.data.experimental.AUTOTUNE
tf.config.run_functions_eagerly(True)

# %%
def convert_to_list(string):
    return [float(i) if i != '' else 0 for i in string.split(', ')]

def process_dataset(df):
    columns = ['time', 'mag', 'flux']
    for i in columns:
        df[i] = df[i].apply(lambda x: x[1:-1])
        df = df[~df[i].isnull()]
        df[i] = df[i].apply(convert_to_list)
    return df

# %%
df = pd.read_csv(r'Final Dataset/final_df_g_complete.csv')
df = process_dataset(df)
df.reset_index(inplace=True)
df.drop(['index'], axis=1, inplace=True)
df.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0     source_id band  \
# 0             0           0  1.051900e+18    G
# 1             3           0  1.113930e+18    G
#
#                                                 time  \
# 0  [1709.0473075002526, 1709.12129661769, 1746.93...
# 1  [1705.0618115528753, 1742.1944699213775, 1781....
#
#                                                  mag  \
# 0  [14.779410003765635, 14.61257323866902, 14.388...
# 1  [11.034948789103318, 10.976913805916949, 11.27...
#
#                                                 flux label
# 0  [23077.180413664224, 26910.232583122888, 33064...   CEP
# 1  [726051.1726333069, 765916.145348983, 580536.1...   CEP

# %%
X = df['mag']
y = df[['label']]

# %%
def onehot_encoder(y):
    k = len(np.unique(y))
    return np.eye(k)[y]

# %%
le = LabelEncoder().fit(y['label'])
y = le.transform(y['label'])
y = onehot_encoder(y)

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size = 0.2, random_state = 42)

# %%
max_words = 261

# %%
prepad_X_train = sequence.pad_sequences(X_train, padding='pre', maxlen = max_words, dtype='float')
prepad_X_train = np.expand_dims(prepad_X_train,axis=2)
prepad_X_val = sequence.pad_sequences(X_val, padding='pre', maxlen = max_words, dtype='float')
prepad_X_val = np.expand_dims(prepad_X_val,axis=2)
prepad_X_test = sequence.pad_sequences(X_test, padding='pre', maxlen = max_words, dtype='float')
prepad_X_test = np.expand_dims(prepad_X_test,axis=2)

# %%
train_data = tf.data.Dataset.from_tensor_slices((prepad_X_train,y_train))
train_data = train_data.shuffle(buffer_size=len(prepad_X_train))
train_data = train_data.batch(32)
train_data = train_data.prefetch(AUTOTUNE)

# %%
val_data = tf.data.Dataset.from_tensor_slices((prepad_X_val,y_val))
val_data = val_data.batch(32)
val_data = val_data.prefetch(AUTOTUNE)

# %%
test_data = tf.data.Dataset.from_tensor_slices((prepad_X_test,y_test))
test_data = test_data.batch(32)
test_data = test_data.prefetch(AUTOTUNE)

# %% [markdown]
# ### Base Model - CNN (Using G Band, unscaled data)

# %% [markdown]
# <font size = "4" color = "#654957">
#     To start with our baseline, we are taking a simple CNN model. Let's see how it performs.
# </font>

# %%
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=20, activation='relu'))
cnn_model.add(Conv1D(filters=64, kernel_size=20, activation='relu'))

cnn_model.add(Flatten())
cnn_model.add(Dense(100, activation='relu'))
cnn_model.add(Dense(4, activation='softmax'))
cnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Create callbacks
checkpoint = ModelCheckpoint('best_model_cnn.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
cnn_history = cnn_model.fit(train_data, validation_data=val_data, epochs = 30, callbacks=callback)
# Out:
# Epoch 1/30
# 7088/7088 [==============================] - ETA: 0s - loss: 0.8185 - accuracy: 0.6247
# Epoch 1: val_loss improved from inf to 0.77444, saving model to best_model_cnn.h5
# 7088/7088 [==============================] - 94s 13ms/step - loss: 0.8185 - accuracy: 0.6247 - val_loss: 0.7744 - val_accuracy: 0.6437 - lr: 0.0010
# Epoch 2/30
# 7088/7088 [==============================] - ETA: 0s - loss: 0.7863 - accuracy: 0.6389
# Epoch 2: val_loss improved from 0.77444 to 0.77408, saving model to best_model_cnn.h5
# 7088/7088 [==============================] - 91s 13ms/step - loss: 0.7863 - accuracy: 0.6389 - val_loss: 0.7741 - val_accuracy: 0.6442 - lr: 0.0010
# Epoch 3/30
# 7085/7088 [============================>.] - ETA: 0s - loss: 0.7835 - accuracy: 0.6414
# Epoch 3: val_loss did not improve from 0.77408
# 7088/7088 [==============================] - 90s 13ms/step - loss: 0.7835 - accuracy: 0.6414 - val_loss: 0.7905 - val_accuracy: 0.6321 - lr: 0.0010
# Epoch 4/30
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((cnn_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((cnn_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((cnn_history.history['loss']), color=color2, label='train loss')
ax2.plot((cnn_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()

# %%
with open('cnn_history.pkl','wb') as f:
    pickle.dump(cnn_history.history,f)

# %%
cnn_test = cnn_model.evaluate(test_data)
# Out:
# 985/985 [==============================] - 9s 9ms/step - loss: 0.7653 - accuracy: 0.6508

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = cnn_model.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.02      0.04      1469
#            1       0.57      0.39      0.46     10060
#            2       0.82      0.94      0.87      9869
#            3       0.55      0.72      0.63     10105
#
#     accuracy                           0.65     31503
#    macro avg       0.69      0.52      0.50     31503
# weighted avg       0.65      0.65      0.62     31503

# %% [markdown]
# <font size = "4" color = "#654957">
#     Validation accuracy over 65%. Not a bad start. Now, we can move forward with more complex models such as RNNs.
# </font>

# %% [markdown]
# ### RNN Model (Using G Band, unscaled data)

# %% [markdown]
# <font size = "4" color = "#654957">
#     Moving forward our second model will be a simpleRNN.
# </font>

# %%
tf.config.run_functions_eagerly(False)

# %%
input_layer = Input(shape = (261,1))
rnn1 = SimpleRNN(64, return_sequences=False)(input_layer)
output = Dense(4, activation='softmax')(rnn1)
rnn_model = Model(inputs=input_layer, outputs=output)
# summarize layers
print(rnn_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 261, 1)]          0
#
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense_2 (Dense)             (None, 4)                 260
#
# ...
# Total params: 4,484
# Trainable params: 4,484
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
rnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Create callbacks
checkpoint = ModelCheckpoint('best_model_rnn.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
rnn_history = rnn_model.fit(train_data, validation_data=val_data, epochs = 10, callbacks=callback)
# Out:
# Epoch 1/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.5942
# Epoch 1: val_loss improved from inf to 0.81544, saving model to best_model_rnn.h5
# 7088/7088 [==============================] - 756s 106ms/step - loss: 0.8210 - accuracy: 0.5942 - val_loss: 0.8154 - val_accuracy: 0.6038 - lr: 0.0010
# Epoch 2/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.8199 - accuracy: 0.5948
# Epoch 2: val_loss did not improve from 0.81544
# 7088/7088 [==============================] - 773s 109ms/step - loss: 0.8199 - accuracy: 0.5948 - val_loss: 0.8189 - val_accuracy: 0.5733 - lr: 0.0010
# Epoch 3/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.8210 - accuracy: 0.5935
# Epoch 3: val_loss did not improve from 0.81544
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((rnn_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((rnn_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((rnn_history.history['loss']), color=color2, label='train loss')
ax2.plot((rnn_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for RNN.')
plt.show()

# %%
with open('rnn_history.pkl','wb') as f:
    pickle.dump(rnn_history.history,f)

# %%
rnn_test = rnn_model.evaluate(test_data)
# Out:
# 985/985 [==============================] - 23s 24ms/step - loss: 0.7937 - accuracy: 0.6058

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = rnn_model.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1469
#            1       0.39      0.05      0.09     10060
#            2       0.80      0.96      0.87      9869
#            3       0.50      0.90      0.64     10105
#
#     accuracy                           0.61     31503
#    macro avg       0.42      0.48      0.40     31503
# weighted avg       0.53      0.61      0.51     31503
# C:\Users\laksh\anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# <font size = "4" color = "#654957">
#     RNNs gave us a validation accuracy of 60.58%.
# </font>

# %% [markdown]
# <font size = "4" color = "#654957">
#     As we all know, RNNs suffer from vanishing gradients and do not store long term information. To overcome that, we will move forward with GRUs and LSTMs.
# </font>

# %% [markdown]
# ### GRU Model (Using G Band, unscaled data)

# %%
input_layer = Input(shape = (261,1))
GRU1 = GRU(64, return_sequences=False)(input_layer)
output = Dense(4, activation='softmax')(GRU1)
gru_model = Model(inputs=input_layer, outputs=output)
# summarize layers
print(gru_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 261, 1)]          0
#
#  gru (GRU)                   (None, 64)                12864
#
#  dense_3 (Dense)             (None, 4)                 260
#
# ...
# Total params: 13,124
# Trainable params: 13,124
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
gru_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Create callbacks
checkpoint = ModelCheckpoint('best_model_gru.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
gru_history = gru_model.fit(train_data, validation_data=val_data, epochs = 30, callbacks=callback)
# Out:
# Epoch 1/30
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.7808 - accuracy: 0.6376
# Epoch 1: val_loss improved from inf to 0.73959, saving model to best_model_gru.h5
# 7088/7088 [==============================] - 95s 13ms/step - loss: 0.7808 - accuracy: 0.6376 - val_loss: 0.7396 - val_accuracy: 0.6559 - lr: 0.0010
# Epoch 2/30
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.6750
# Epoch 2: val_loss improved from 0.73959 to 0.58953, saving model to best_model_gru.h5
# 7088/7088 [==============================] - 91s 13ms/step - loss: 0.7263 - accuracy: 0.6750 - val_loss: 0.5895 - val_accuracy: 0.7923 - lr: 0.0010
# Epoch 3/30
# 7084/7088 [============================>.] - ETA: 0s - loss: 0.3909 - accuracy: 0.8652
# Epoch 3: val_loss improved from 0.58953 to 0.23462, saving model to best_model_gru.h5
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((gru_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((gru_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((gru_history.history['loss']), color=color2, label='train loss')
ax2.plot((gru_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for GRU.')
plt.show()

# %%
with open('gru_history.pkl','wb') as f:
    pickle.dump(gru_history.history,f)

# %%
gru_test = gru_model.evaluate(test_data)
# Out:
# 985/985 [==============================] - 5s 6ms/step - loss: 0.0621 - accuracy: 0.9800

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = gru_model.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81      1469
#            1       0.99      0.99      0.99     10060
#            2       0.98      0.99      0.99      9869
#            3       0.98      0.99      0.99     10105
#
#     accuracy                           0.98     31503
#    macro avg       0.96      0.93      0.94     31503
# weighted avg       0.98      0.98      0.98     31503

# %% [markdown]
# <font size = "4" color = "#654957">
#     GRUs gave us a validation accuracy of 98%.
# </font>

# %% [markdown]
# ### LSTM Model (Using G Band, unscaled data)

# %%
input_layer = Input(shape = (261,1))
LSTM1 = LSTM(64, return_sequences=False)(input_layer)
output = Dense(4, activation='softmax')(LSTM1)
lstm_model = Model(inputs=input_layer, outputs=output)
# summarize layers
print(lstm_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 261, 1)]          0
#
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense_4 (Dense)             (None, 4)                 260
#
# ...
# Total params: 17,156
# Trainable params: 17,156
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Create callbacks
checkpoint = ModelCheckpoint('best_model_lstm.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
lstm_history = lstm_model.fit(train_data, validation_data=val_data, epochs = 30, callbacks=callback)
# Out:
# Epoch 1/30
# 7088/7088 [==============================] - ETA: 0s - loss: 0.7885 - accuracy: 0.6333
# Epoch 1: val_loss improved from inf to 0.74102, saving model to best_model_lstm.h5
# 7088/7088 [==============================] - 94s 13ms/step - loss: 0.7885 - accuracy: 0.6333 - val_loss: 0.7410 - val_accuracy: 0.6578 - lr: 0.0010
# Epoch 2/30
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.7434 - accuracy: 0.6559
# Epoch 2: val_loss did not improve from 0.74102
# 7088/7088 [==============================] - 95s 13ms/step - loss: 0.7434 - accuracy: 0.6559 - val_loss: 0.7509 - val_accuracy: 0.6490 - lr: 0.0010
# Epoch 3/30
# 7088/7088 [==============================] - ETA: 0s - loss: 0.7177 - accuracy: 0.6709
# Epoch 3: val_loss improved from 0.74102 to 0.67892, saving model to best_model_lstm.h5
# 7088/7088 [==============================] - 96s 14ms/step - loss: 0.7177 - accuracy: 0.6709 - val_loss: 0.6789 - val_accuracy: 0.7231 - lr: 0.0010
# Epoch 4/30
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((lstm_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((lstm_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((lstm_history.history['loss']), color=color2, label='train loss')
ax2.plot((lstm_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for LSTM.')
plt.show()

# %%
with open('lstm_history.pkl','wb') as f:
    pickle.dump(lstm_history.history,f)

# %%
lstm_test = lstm_model.evaluate(test_data)
# Out:
# 985/985 [==============================] - 5s 5ms/step - loss: 0.0689 - accuracy: 0.9768

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = lstm_model.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.79      1469
#            1       0.98      0.99      0.99     10060
#            2       0.98      0.99      0.99      9869
#            3       0.98      0.98      0.98     10105
#
#     accuracy                           0.98     31503
#    macro avg       0.95      0.93      0.94     31503
# weighted avg       0.98      0.98      0.98     31503

# %% [markdown]
# <font size = "4" color = "#654957">
#     LSTMs gave us a validation accuracy of 97.68%.
# </font>

# %% [markdown]
# ### LSTM Model 2 (Using G Band, unscaled data)

# %% [markdown]
# <font size = "4" color = "#654957">
#     As we already know, stacking layers improve model performance. As our previous LSTM performed very well. We'll be making another LSTM inspired model by stacking multiple LSTM layers.
# </font>

# %%
input_layer = Input(shape = (261,1))
LSTM1 = LSTM(64, return_sequences=True)(input_layer)
LSTM2 = LSTM(64, return_sequences=True)(LSTM1)
LSTM3 = LSTM(64, return_sequences=False)(LSTM2)
output = Dense(4, activation='softmax')(LSTM3)
lstm_model_2 = Model(inputs=input_layer, outputs=output)
# summarize layers
print(lstm_model_2.summary())
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 261, 1)]          0
#
#  lstm_4 (LSTM)               (None, 261, 64)           16896
#
#  lstm_5 (LSTM)               (None, 261, 64)           33024
#
#  lstm_6 (LSTM)               (None, 64)                33024
#
#  dense_6 (Dense)             (None, 4)                 260
#
# ...
# Total params: 83,204
# Trainable params: 83,204
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm_model_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Create callbacks
checkpoint = ModelCheckpoint('best_model_lstm_2.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
lstm_history_2 = lstm_model_2.fit(train_data, validation_data=val_data, epochs = 10, callbacks=callback)
# Out:
# Epoch 1/10
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.7715 - accuracy: 0.6426
# Epoch 1: val_loss improved from inf to 0.72956, saving model to best_model_lstm_2.h5
# 7088/7088 [==============================] - 270s 38ms/step - loss: 0.7716 - accuracy: 0.6426 - val_loss: 0.7296 - val_accuracy: 0.6542 - lr: 0.0010
# Epoch 2/10
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.8622
# Epoch 2: val_loss improved from 0.72956 to 0.09955, saving model to best_model_lstm_2.h5
# 7088/7088 [==============================] - 265s 37ms/step - loss: 0.3455 - accuracy: 0.8622 - val_loss: 0.0995 - val_accuracy: 0.9678 - lr: 0.0010
# Epoch 3/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9687
# Epoch 3: val_loss improved from 0.09955 to 0.08019, saving model to best_model_lstm_2.h5
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((lstm_history_2.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((lstm_history_2.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((lstm_history_2.history['loss']), color=color2, label='train loss')
ax2.plot((lstm_history_2.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for Multi Layered LSTM.')
plt.show()

# %%
with open('lstm_history_2.pkl','wb') as f:
    pickle.dump(lstm_history_2.history,f)

# %%
lstm_2_test = lstm_model_2.evaluate(test_data)
# Out:
# 985/985 [==============================] - 16s 16ms/step - loss: 0.0574 - accuracy: 0.9816

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = lstm_model_2.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1469
#            1       0.99      1.00      0.99     10060
#            2       0.99      0.98      0.99      9869
#            3       0.99      0.99      0.99     10105
#
#     accuracy                           0.98     31503
#    macro avg       0.96      0.95      0.95     31503
# weighted avg       0.98      0.98      0.98     31503

# %% [markdown]
# <font size = "4" color = "#654957">
#     Accuracy of Multi Layered LSTM : 98.16%, which is the highest till now.

# %% [markdown]
# ## Pre- Processing 🤖

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Embedding, SimpleRNN, Input, Reshape, LSTM
from tensorflow.keras.preprocessing import sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import Model
from tensorflow.keras.models import save_model, load_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from scipy.interpolate import interp1d
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import pickle
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
def convert_to_list(string):
    return [float(i) if i != '' else 0 for i in string.split(', ')]

def process_dataset(df):
    columns = ['time', 'mag', 'flux']
    for i in columns:
        df[i] = df[i].apply(lambda x: x[1:-1])
        df = df[~df[i].isnull()]
        df[i] = df[i].apply(convert_to_list)
    return df

def interpolate_(data, num = 261):
    x = data['time']
    y = data['mag']
    new_mag = []
    new_time = []
    for i in range(len(data)):
        t = data.iloc[i]['time']
        x = data.iloc[i]['mag']
        newt = np.linspace(min(t), max(t), num, endpoint=True)
        f = interp1d(t, x)
        newx = f(newt)
        new_mag.append(newx)
        new_time.append(newt)
    df_t = pd.DataFrame({"intrpol_time":[i for i in new_time], "intrpol_mag": [i for i in new_mag]})
    return df_t

def scale(data):
    new_mag = []
    for i in range(len(data)):
        mean_ = np.mean(data.iloc[i]['intrpol_mag'])
        std_ = np.std(data.iloc[i]['intrpol_mag'])
        scaled_v = (data.iloc[i]['intrpol_mag'] - mean_) / std_
        new_mag.append(list(scaled_v))
    return [i for i in new_mag]

def onehot_encoder(y):
    k = len(np.unique(y))
    return np.eye(k)[y]

# %%
df =  pd.read_csv(r'Final Dataset\final_df_g_complete.csv', index_col = 0)
df = process_dataset(df)
df.reset_index(inplace=True)
df.drop(['index'], axis=1, inplace=True)
df.head(2)
# Out:
#    Unnamed: 0     source_id band  \
# 0           0  1.051900e+18    G
# 1           0  1.113930e+18    G
#
#                                                 time  \
# 0  [1709.0473075002526, 1709.12129661769, 1746.93...
# 1  [1705.0618115528753, 1742.1944699213775, 1781....
#
#                                                  mag  \
# 0  [14.779410003765635, 14.61257323866902, 14.388...
# 1  [11.034948789103318, 10.976913805916949, 11.27...
#
#                                                 flux label
# 0  [23077.180413664224, 26910.232583122888, 33064...   CEP
# 1  [726051.1726333069, 765916.145348983, 580536.1...   CEP

# %%
df = pd.concat([df, interpolate_(df[['time','mag']])], axis = 1)

# %%
df['scaled_mag'] = scale(df)

# %%
X = df['scaled_mag']
y = df[['label']]

# %%
le = LabelEncoder().fit(y['label'])
y = le.transform(y['label'])
y = onehot_encoder(y)

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size = 0.2, random_state = 42)

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train.to_list(),y_train))
train_data = train_data.shuffle(buffer_size=len(X_train.to_list()))
train_data = train_data.batch(32)
train_data = train_data.prefetch(AUTOTUNE)

# %%
val_data = tf.data.Dataset.from_tensor_slices((X_val.to_list(),y_val))
val_data = val_data.batch(32)
val_data = val_data.prefetch(AUTOTUNE)

# %%
test_data = tf.data.Dataset.from_tensor_slices((X_test.to_list(),y_test))
test_data = test_data.batch(32)
test_data = test_data.prefetch(AUTOTUNE)

# %% [markdown]
# ## Modelling Part 2 🧠

# %% [markdown]
# ### LSTM with Interpolation

# %%
input_layer = Input(shape = (261,1))
LSTM1 = LSTM(64, return_sequences=True)(input_layer)
LSTM2 = LSTM(64, return_sequences=True)(LSTM1)
LSTM3 = LSTM(64, return_sequences=False)(LSTM2)
output = Dense(4, activation='softmax')(LSTM3)
lstm_model_3 = Model(inputs=input_layer, outputs=output)
# summarize layers
print(lstm_model_3.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 261, 1)]          0
#
#  lstm_1 (LSTM)               (None, 261, 64)           16896
#
#  lstm_2 (LSTM)               (None, 261, 64)           33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 4)                 260
#
# ...
# Total params: 83,204
# Trainable params: 83,204
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm_model_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint('best_model_lstm_3.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
lstm_3_history = lstm_model_3.fit(train_data, validation_data=val_data, epochs = 10, callbacks=callback)
# Out:
# Epoch 1/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.8594
# Epoch 1: val_loss improved from inf to 0.17781, saving model to best_model_lstm_3.h5
# 7088/7088 [==============================] - 256s 36ms/step - loss: 0.3865 - accuracy: 0.8594 - val_loss: 0.1778 - val_accuracy: 0.9397 - lr: 0.0010
# Epoch 2/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9474
# Epoch 2: val_loss improved from 0.17781 to 0.14427, saving model to best_model_lstm_3.h5
# 7088/7088 [==============================] - 254s 36ms/step - loss: 0.1598 - accuracy: 0.9474 - val_loss: 0.1443 - val_accuracy: 0.9506 - lr: 0.0010
# Epoch 3/10
# 7088/7088 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9587
# Epoch 3: val_loss improved from 0.14427 to 0.11900, saving model to best_model_lstm_3.h5
# ...

# %%
lstm_3_test = lstm_model_3.evaluate(test_data)
# Out:
# 985/985 [==============================] - 15s 15ms/step - loss: 0.0866 - accuracy: 0.9730

# %%
with open('lstm_3_history.pkl','wb') as f:
    pickle.dump(lstm_3_history.history,f)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((lstm_3_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((lstm_3_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((lstm_3_history.history['loss']), color=color2, label='train loss')
ax2.plot((lstm_3_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for Multi Layered LSTM.')
plt.show()

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = lstm_model_3.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.66      0.77      1469
#            1       0.98      0.99      0.99     10060
#            2       0.97      0.99      0.98      9869
#            3       0.98      0.98      0.98     10105
#
#     accuracy                           0.97     31503
#    macro avg       0.96      0.91      0.93     31503
# weighted avg       0.97      0.97      0.97     31503

# %% [markdown]
# ### LSTM with Interpolation and time difference as input

# %%
def difference_time(time_arr):
    diff_list = [0]
    for i in range(1,len(time_arr)):
        x = time_arr[i] - time_arr[i-1]
        diff_list.append(x)
    return diff_list

# %%
time_diff = []
for i in df.index:
    diff = difference_time(df['intrpol_time'][i])
    time_diff.append(diff)

# %%
df['time_diff'] = time_diff
del time_diff

# %%
df.head(2)
# Out:
#    Unnamed: 0     source_id band  \
# 0           0  1.051900e+18    G
# 1           0  1.113930e+18    G
#
#                                                 time  \
# 0  [1709.0473075002526, 1709.12129661769, 1746.93...
# 1  [1705.0618115528753, 1742.1944699213775, 1781....
#
#                                                  mag  \
# 0  [14.779410003765635, 14.61257323866902, 14.388...
# 1  [11.034948789103318, 10.976913805916949, 11.27...
#
#                                                 flux label  \
# 0  [23077.180413664224, 26910.232583122888, 33064...   CEP
# 1  [726051.1726333069, 765916.145348983, 580536.1...   CEP
#
#                                         intrpol_time  \
# 0  [1709.0473075002526, 1712.8653487747863, 1716....
# 1  [1705.0618115528753, 1708.8904308894864, 1712....
#
#                                          intrpol_mag  \
# 0  [14.779410003765635, 14.590431795392403, 14.56...
# 1  [11.034948789103318, 11.028965003708203, 11.02...
#
# ...

# %%
X = df[['time_diff','scaled_mag']]
y = df[['label']]

# %%
time = X['time_diff']
mag = X['scaled_mag']

# %%
X_stack = np.column_stack([time, mag])

# %%
X_stack.shape
# Out:
# (315021, 2)

# %%
X_stacked_final = []
for i in range(len(X_stack[:,0])):
    X_stacked_final.append(np.column_stack([X_stack[:,0][i], X_stack[:,1][i]]))

# %%
np.array(X_stacked_final).shape
# Out:
# (315021, 261, 2)

# %%
le = LabelEncoder().fit(y['label'])
y = le.transform(y['label'])
y = onehot_encoder(y)

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X_stacked_final, y, test_size = 0.1, random_state = 42)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size = 0.2, random_state = 42)

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train,y_train))
train_data = train_data.shuffle(buffer_size=len(X_train))
train_data = train_data.batch(32)
train_data = train_data.prefetch(AUTOTUNE)

# %%
val_data = tf.data.Dataset.from_tensor_slices((X_val,y_val))
val_data = val_data.batch(32)
val_data = val_data.prefetch(AUTOTUNE)

# %%
test_data = tf.data.Dataset.from_tensor_slices((X_test,y_test))
test_data = test_data.batch(32)
test_data = test_data.prefetch(AUTOTUNE)

# %%
input_layer = Input(shape = (261,2))
LSTM1 = LSTM(64, return_sequences=True)(input_layer)
LSTM2 = LSTM(64, return_sequences=True)(LSTM1)
LSTM3 = LSTM(64, return_sequences=False)(LSTM2)
output = Dense(4, activation='softmax')(LSTM3)
lstm_model_4 = Model(inputs=input_layer, outputs=output)
# summarize layers
print(lstm_model_4.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 261, 2)]          0
#
#  lstm (LSTM)                 (None, 261, 64)           17152
#
#  lstm_1 (LSTM)               (None, 261, 64)           33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 4)                 260
#
# ...
# Total params: 83,460
# Trainable params: 83,460
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
lstm_model_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint('best_model_lstm_4.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, mode='min',restore_best_weights=True)
lr = ReduceLROnPlateau(patience=2, verbose=1, monitor='val_loss',min_lr=1e-4, mode='min', restore_best_weights=True)
callback = [checkpoint, early_stop, lr]

# %%
lstm_4_history = lstm_model_4.fit(train_data, validation_data=val_data, epochs = 10, callbacks=callback)
# Out:
# Epoch 1/10
# 7087/7088 [============================>.] - ETA: 0s - loss: 1.2049 - accuracy: 0.3545
# Epoch 1: val_loss improved from inf to 0.76020, saving model to best_model_lstm_4.h5
# 7088/7088 [==============================] - 259s 36ms/step - loss: 1.2048 - accuracy: 0.3546 - val_loss: 0.7602 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 2/10
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.2369 - accuracy: 0.9211
# Epoch 2: val_loss improved from 0.76020 to 0.16509, saving model to best_model_lstm_4.h5
# 7088/7088 [==============================] - 254s 36ms/step - loss: 0.2369 - accuracy: 0.9211 - val_loss: 0.1651 - val_accuracy: 0.9464 - lr: 0.0010
# Epoch 3/10
# 7087/7088 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9509
# Epoch 3: val_loss improved from 0.16509 to 0.13216, saving model to best_model_lstm_4.h5
# ...

# %%
lstm_4_test = lstm_model_4.evaluate(test_data)
# Out:
# 985/985 [==============================] - 15s 15ms/step - loss: 0.0834 - accuracy: 0.9731

# %%
with open('lstm_4_history.pkl','wb') as f:
    pickle.dump(lstm_4_history.history,f)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,6))
color1 = 'tab:cyan'
color1b = 'tab:blue'
ax1.plot((lstm_4_history.history['accuracy']), color=color1 ,label='train accuracy')
ax1.plot((lstm_4_history.history['val_accuracy']), color=color1b ,label='val accuracy')
ax1.set_xlabel(r'Epoch', fontsize=20)
ax1.set_ylabel(r'Accuracy', color=color1, fontsize=20)
ax1.tick_params(axis='y', labelsize=20, labelcolor=color1)
ax1.legend()

ax2 = ax1.twinx()

color2 = 'tab:pink'
color2b = 'tab:red'
ax2.plot((lstm_4_history.history['loss']), color=color2, label='train loss')
ax2.plot((lstm_4_history.history['val_loss']), color=color2b, label='val loss')
ax2.set_ylabel(r'Loss', color=color2, fontsize=20)
ax2.tick_params(axis='y', labelsize=20, labelcolor=color2)
ax2.legend()
plt.suptitle('Accuracy and Loss plot for Multi Layered LSTM with Interpolation and Input Time Difference.')
plt.show()

# %%
y_pred = []  
y_true = []  


for x, y in test_data:   
   
   y_true.append(y)
   
   preds = lstm_model_4.predict(x)
   
   y_pred.append(np.argmax(preds, axis = - 1))


correct_labels = tf.concat([item for item in y_true], axis = 0)
predicted_labels = tf.concat([item for item in y_pred], axis = 0)

correct_labels = np.argmax(correct_labels, axis = 1)
# Out:
# ...
# 1/1 [==============================] - 1s 798ms/step

# %%
ConfusionMatrixDisplay.from_predictions(correct_labels, predicted_labels)
plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78      1469
#            1       0.99      0.99      0.99     10060
#            2       0.97      0.99      0.98      9869
#            3       0.97      0.98      0.98     10105
#
#     accuracy                           0.97     31503
#    macro avg       0.94      0.92      0.93     31503
# weighted avg       0.97      0.97      0.97     31503
